# %% [markdown]
# <a href="https://colab.research.google.com/github/Gursewak-S/Advance-Python/blob/main/practice(merge%2Cconcat).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
C = pd.read_csv("/content/Courses.csv")
S = pd.read_csv("/content/student_info.csv")

# %%
pd.DataFrame(C)
# Out:
#     ID  Course
# 0  101    Java
# 1  102  Python
# 2  104    Mern
# 3  105  Python
# 4  106    Java
# 5  108     C++
# 6  109     AWS
# 7  110     AWS

# %%
pd.DataFrame(S)
# Out:
#     ID    Name  Age Grade       City
# 0  101    Aman   20     A      Delhi
# 1  102  Bhavya   21     B     Mumbai
# 2  103  Chetan   19     A    Chennai
# 3  104   Divya   22     C    Kolkata
# 4  105  Eshaan   20     B  Bangalore
# 5  106  Fatima   21     A  Hyderabad
# 6  107  Gaurav   23     B       Pune
# 7  108    Hina   19     C     Jaipur
# 8  109  Ishaan   22     A    Lucknow
# 9  110    Jaya   20     B  Ahmedabad

# %%
m = pd.merge(S, C, how='left',  on='ID')
m
# Out:
#     ID    Name  Age Grade       City  Course
# 0  101    Aman   20     A      Delhi    Java
# 1  102  Bhavya   21     B     Mumbai  Python
# 2  103  Chetan   19     A    Chennai     NaN
# 3  104   Divya   22     C    Kolkata    Mern
# 4  105  Eshaan   20     B  Bangalore  Python
# 5  106  Fatima   21     A  Hyderabad    Java
# 6  107  Gaurav   23     B       Pune     NaN
# 7  108    Hina   19     C     Jaipur     C++
# 8  109  Ishaan   22     A    Lucknow     AWS
# 9  110    Jaya   20     B  Ahmedabad     AWS

# %%
m=S.merge(C,how='inner',on='ID')
m
# Out:
#     ID    Name  Age Grade       City  Course
# 0  101    Aman   20     A      Delhi    Java
# 1  102  Bhavya   21     B     Mumbai  Python
# 2  104   Divya   22     C    Kolkata    Mern
# 3  105  Eshaan   20     B  Bangalore  Python
# 4  106  Fatima   21     A  Hyderabad    Java
# 5  108    Hina   19     C     Jaipur     C++
# 6  109  Ishaan   22     A    Lucknow     AWS
# 7  110    Jaya   20     B  Ahmedabad     AWS

# %%
data1 = {
    "key": [1, 2, 3],
    "name": ["anmol", "gursewak", "prakul"],
    "age": [23, 22, 20],
    "Stream": ["Data Science", "Data Analyst", "Python Developer"]
}

data2 = {
    "key": [4, 5, 6],
    "name": ["Ansul", "Heeman", "Vineet"],
    "age": [23, 22, 24],
    "Stream": ["AWS", "Djanngo", "Python Developer"]
}

# %%
df = pd.DataFrame(data1, index=[0, 1, 2])

# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data2, index=[3, 4, 5])

# %%
con = pd.concat([df, df1])
con
# Out:
#    key      name  age            Stream
# 0    1     anmol   23      Data Science
# 1    2  gursewak   22      Data Analyst
# 2    3    prakul   20  Python Developer
# 3    4     Ansul   23               AWS
# 4    5    Heeman   22           Djanngo
# 5    6    Vineet   24  Python Developer
