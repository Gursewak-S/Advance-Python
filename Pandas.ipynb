# %% [markdown]
# <a href="https://colab.research.google.com/github/Gursewak-S/Advance-Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Panda => pandas is an open-source library that is used for handle data manipulation.

# %%
# for installing

# !pip install pandas

# %%
# Data Structure of Pandas :
# (1). Series •--› It is one-dimensional array and it shows only values not column name.
# (2). DataFrame --› It is multi-dimensional array and it shows values with column name .

# %% [markdown]
# # (1). Series

# %%
import pandas as pd

# %%
a = pd.Series([1,65,34,800])
a
# Out:
# 0      1
# 1     65
# 2     34
# 3    800
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # (2). DataFrame

# %%
# Q.1 We have to create employee data using dictionary ?

a = {
    "Emp_ID": [1, 2,3,4,5,6,7,8],
    "Emp Name": ['Sam', 'Raj', 'Mohit', 'Sam', 'Gorav', 'Mohit', 'Mohit', 'Garvit'],
    "Department": ['IT', 'Sales', 'IT', 'Operations', 'HR', 'IT', 'Operations', 'HR'],
    "Working_hours": [8,9,9,9,9,8,8,8],
    "Salary": [23000,25000,35000,31000,28000,26000, 30000, 34000]
}

# %%
type(a)
# Out:
# dict

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_ID Emp Name  Department  Working_hours  Salary
# 0       1      Sam          IT              8   23000
# 1       2      Raj       Sales              9   25000
# 2       3    Mohit          IT              9   35000
# 3       4      Sam  Operations              9   31000
# 4       5    Gorav          HR              9   28000
# 5       6    Mohit          IT              8   26000
# 6       7    Mohit  Operations              8   30000
# 7       8   Garvit          HR              8   34000

# %% [markdown]
# # How do you export our dataframe into csv file? (Jupiter)

# %%
# df.to_csv("file_location", index =False)

# %% [markdown]
# # HOW DO YOU IMPORT OUR DATAFRAME INTO JUPYTER NOTEBOOK ?

# %%
# open a folder in which you have datasets .
# copy the folder Location
# paste it into jupyternotebook
# df = pd.read_csv("paste_folder_location//file_name.csv")

# %% [markdown]
# Method 1

# %%
# df = pd.read_csv("File_location")
# df

# %% [markdown]
# Method 2

# %%
# Go to home page of jupyter .
# click on upload.
# click on open --› upload.
# pd.read_csv("fiLename.csv")

# %%
# df = pd.read_csv("cars.csv")
# df

# %% [markdown]
# # How do you export our dataframe into csv file? (Collab)

# %%
df.to_csv("/content/emp.csv")

# %% [markdown]
# # Import

# %%
a = pd.read_csv("/content/emp.csv")
a
# Out:
#    Unnamed: 0  Emp_ID Emp Name  Department  Working_hours  Salary
# 0           0       1      Sam          IT              8   23000
# 1           1       2      Raj       Sales              9   25000
# 2           2       3    Mohit          IT              9   35000
# 3           3       4      Sam  Operations              9   31000
# 4           4       5    Gorav          HR              9   28000
# 5           5       6    Mohit          IT              8   26000
# 6           6       7    Mohit  Operations              8   30000
# 7           7       8   Garvit          HR              8   34000

# %%
data = pd.read_csv("/content/student_info.csv")
data
# Out:
#     ID    Name  Age Grade       City
# 0  101    Aman   20     A      Delhi
# 1  102  Bhavya   21     B     Mumbai
# 2  103  Chetan   19     A    Chennai
# 3  104   Divya   22     C    Kolkata
# 4  105  Eshaan   20     B  Bangalore
# 5  106  Fatima   21     A  Hyderabad
# 6  107  Gaurav   23     B       Pune
# 7  108    Hina   19     C     Jaipur
# 8  109  Ishaan   22     A    Lucknow
# 9  110    Jaya   20     B  Ahmedabad

# %%
df = pd.read_csv("/content/covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.shape    # rows , column
# Out:
# (100, 6)

# %%
df.size  # rows*column
# Out:
# 600

# %%
df.columns # it will return all the column
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
# if you want to find top data from dataframe then you can use head()

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
# if you want to find last data from dataframe then use tail

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.tail(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
# if you want to find randomly indexed data then

# %%
df.sample(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 57   49  Female   99.0  Strong  Bangalore        No
# 36   38  Female  101.0    Mild  Bangalore        No
# 13   64    Male  102.0    Mild  Bangalore       Yes

# %%
# specific elements

# %%
# loc method [row_range, column_name]
df.loc[3:5, ["age", "has_covid"]]
# Out:
#    age has_covid
# 3   31        No
# 4   65        No
# 5   84       Yes

# %%
#  iloc method [row_range, column_range]
df.iloc[3:5, [1,3,4]]
# Out:
#    gender cough     city
# 3  Female  Mild  Kolkata
# 4  Female  Mild   Mumbai

# %% [markdown]
# # DataFrame is Mutable

# %%
df.head(4)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No

# %%
df['has_covid'][2]
# Out:
# 'No'

# %%
df['has_covid'][2] = 'Yes'
# Out:
# <ipython-input-23-3bfa6c299dbf>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['has_covid'][2] = 'Yes'
# <ipython-input-23-3bfa6c299dbf>:1: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi       Yes
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
# specific column ---> data ---> df['column_name'][indexing]

# %%
df['gender'][2:5]
# Out:
# 2      Male
# 3    Female
# 4    Female
# Name: gender, dtype: object

# %% [markdown]
# # If you want to check overall information then

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    object
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    object
#  4   city       100 non-null    object
#  5   has_covid  100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# # If you want to check statically view of data then you can use describe()

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %% [markdown]
# # If you want to check how many elements are available in a particular column

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     54
# Yes    46
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    59
# Male      41
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
# Data -----›
# (1). Numerical ---› Continuous data ---› DOB(23 years, 5 months, 6 days) , Salary(13567.45) ,
# weights (56.34) , km(35.57)

# (2). Categorical ----› Descrete data ----› Total_Number_of_students_in_a_class, Marital status,
# df['categorical_coLumn'][ 'Numerical '].aggregation_function()

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/flipkart.csv")

# %%
data
# Out:
#                                           CGtC98 href  \
# 0   https://www.flipkart.com/dell-vostro-3520-inte...
# 1   https://www.flipkart.com/dell-inspiron-3535-ms...
# 2   https://www.flipkart.com/hp-touch-chromebook-m...
# 3   https://www.flipkart.com/hp-15s-amd-ryzen-3-qu...
# 4   https://www.flipkart.com/hp-victus-intel-core-...
# 5   https://www.flipkart.com/dell-vostro-3520-inte...
# 6   https://www.flipkart.com/hp-15s-intel-core-i5-...
# 7   https://www.flipkart.com/hp-amd-ryzen-5-hexa-c...
# 8   https://www.flipkart.com/hp-250r-g9-intel-core...
# 9   https://www.flipkart.com/hp-g9-intel-core-i3-1...
# 10  https://www.flipkart.com/msi-cyborg-15-ai-pc-i...
# 11  https://www.flipkart.com/msi-thin-a15-amd-ryze...
# 12  https://www.flipkart.com/hp-15s-amd-ryzen-3-du...
# 13  https://www.flipkart.com/hp-15s-intel-core-i3-...
# 14  https://www.flipkart.com/hp-15r-2025-intel-cor...
# 15  https://www.flipkart.com/hp-amd-ryzen-5-quad-c...
# ...

# %%
data.head(4)
# Out:
#                                          CGtC98 href  \
# 0  https://www.flipkart.com/dell-vostro-3520-inte...
# 1  https://www.flipkart.com/dell-inspiron-3535-ms...
# 2  https://www.flipkart.com/hp-touch-chromebook-m...
# 3  https://www.flipkart.com/hp-15s-amd-ryzen-3-qu...
#
#                                           DByuf4 src          uu79Xy  \
# 0  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 1  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 2  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 3  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
#
#                                               KzDlHZ  XQDdHH  \
# 0  DELL Vostro 3520 Intel Core i5 12th Gen 1235U ...     4.1
# 1  DELL Inspiron 3535 MSO 2024 AMD Ryzen 5 Quad C...     NaN
# 2  HP Touch Chromebook MediaTek MT8183 - (4 GB/32...     3.3
# 3  HP 15s AMD Ryzen 3 Quad Core 7320U - (8 GB/512...     4.2
#
# ...

# %%
data.tail(3)
# Out:
#                                           CGtC98 href  \
# 23  https://www.flipkart.com/hp-intel-core-i3-12th...
# 24                                                NaN
# 25                                                NaN
#
#                                            DByuf4 src          uu79Xy  \
# 23  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 24                                                NaN             NaN
# 25                                                NaN             NaN
#
#                                                KzDlHZ  XQDdHH  \
# 23  HP Intel Core i3 12th Gen 1215U - (16 GB/512 G...     4.2
# 24                                                NaN     NaN
# 25                                                NaN     NaN
#
#                                            Rza2QY src         Wphh3N hG7V+4  \
# 23  ......  6,814 Ratings      &
# 24                                                NaN            NaN    NaN
# ...

# %%
data.sample(3)
# Out:
#                                           CGtC98 href  \
# 23  https://www.flipkart.com/hp-intel-core-i3-12th...
# 9   https://www.flipkart.com/hp-g9-intel-core-i3-1...
# 10  https://www.flipkart.com/msi-cyborg-15-ai-pc-i...
#
#                                            DByuf4 src          uu79Xy  \
# 23  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 9   https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
# 10  https://rukminim2.flixcart.com/image/312/312/x...  Add to Compare
#
#                                                KzDlHZ  XQDdHH  \
# 23  HP Intel Core i3 12th Gen 1215U - (16 GB/512 G...     4.2
# 9   HP G9 Intel Core i3 13th Gen 1315U Turbo Boost...     3.7
# 10  MSI Cyborg 15 AI PC Intel Core Ultra 5 125H - ...     NaN
#
#                                            Rza2QY src         Wphh3N hG7V+4  \
# 23  ......  6,814 Ratings      &
# 9   ......     37 Ratings      &
# ...

# %%
data.describe()
# Out:
#           XQDdHH
# count  20.000000
# mean    4.125000
# std     0.356703
# min     3.300000
# 25%     4.025000
# 50%     4.200000
# 75%     4.225000
# max     5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CGtC98 href  24 non-null     object
#  1   DByuf4 src   24 non-null     object
#  2   uu79Xy       24 non-null     object
#  3   KzDlHZ       24 non-null     object
#  4   XQDdHH       20 non-null     float64
#  5   Rza2QY src   20 non-null     object
#  6   Wphh3N       20 non-null     object
#  7   hG7V+4       20 non-null     object
#  8   Wphh3N 2     20 non-null     object
#  9   J+igdf       24 non-null     object
#  10  J+igdf 2     24 non-null     object
#  11  J+igdf 3     24 non-null     object
#  12  J+igdf 4     24 non-null     object
#  13  J+igdf 5     24 non-null     object
#  14  J+igdf 6     23 non-null     object
#  15  Nx9bqj       24 non-null     object
#  16  yRaY8j       23 non-null     object
#  17  UkUFwK       23 non-null     object
# ...

# %%
a = data.iloc[1:5, [3,9,16]]
a
# Out:
#                                               KzDlHZ  \
# 1  DELL Inspiron 3535 MSO 2024 AMD Ryzen 5 Quad C...
# 2  HP Touch Chromebook MediaTek MT8183 - (4 GB/32...
# 3  HP 15s AMD Ryzen 3 Quad Core 7320U - (8 GB/512...
# 4  HP Victus Intel Core i5 12th Gen 12450H - (8 G...
#
#                                J+igdf   yRaY8j
# 1     AMD Ryzen 5 Quad Core Processor  ₹48,982
# 2           MediaTek MT8183 Processor  ₹37,241
# 3     AMD Ryzen 3 Quad Core Processor  ₹45,438
# 4  Intel Core i5 Processor (12th Gen)  ₹75,142

# %%
a.to_csv("/content/Laptop_data.csv", index = False)

# %%
import pandas as pd

# %%
p = pd.read_csv("/content/placement.csv")
p
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
p.head(4)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
p.tail(5)
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
p.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
p.loc[1:3, ['cgpa', 'resume_score']]
# Out:
#    cgpa  resume_score
# 1  6.17          5.17
# 2  8.27          8.86
# 3  6.88          7.27

# %%
p.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p.dtypes
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
p.empty  # it return true if there an missing data in dataFrame otherwise return false.
# Out:
# False

# %%
p.isnull().sum() # for check missing value
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
p.dropna() # for removing missing row
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
p.ndim
# Out:
# 2

# %%
p.shape   # shape = n(rows), n(column)
# Out:
# (100, 3)

# %%
p.size    # row count * column count
# Out:
# 300

# %%
p.values # fet a numpy array for data without returning column name
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
p = p.copy()

# %%
a = p.sort_values(by = 'resume_score')
a
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
b = p.sort_index()
b
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# x = p.astype(int)   # type converstion

p['cgpa'] = p['cgpa'].astype(int)

# %%
p
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
# t = df.add(4)

p['cgpa'] = p['cgpa'].add(4)

# %%
p
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
s = p.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
c = p.max()
c
# Out:
# cgpa            13.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
d = p.min()
d
# Out:
# cgpa            9.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
e = p['cgpa'].mean()
e
# Out:
# 10.47

# %%
e = p.mean()
e
# Out:
# cgpa            10.4700
# resume_score     6.9305
# placed           0.5000
# dtype: float64

# %%
f = p['cgpa'].median()
f
# Out:
# 10.0

# %%
s= p.sum()
s
# Out:
# cgpa            1047.00
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
g = p.filter(items = ['cgpa', 'placed'])
g
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
# Another way of filtering

p[['cgpa', 'placed']]
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
s = p.filter(items = [5,6], axis =0)  # axis = 0 mean row wise operation and axis = 1 mean column wise
s
# Out:
#    cgpa  resume_score  placed
# 5    12          6.19       1
# 6     9          7.09       0

# %%
# p.to_excel("/content/data.xlsx")

# %%
p.columns
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
p.values
# Out:
# array([[12.  ,  6.52,  1.  ],
#        [10.  ,  5.17,  0.  ],
#        [12.  ,  8.86,  1.  ],
#        [10.  ,  7.27,  1.  ],
#        [11.  ,  7.3 ,  1.  ],
#        [12.  ,  6.19,  1.  ],
#        [ 9.  ,  7.09,  0.  ],
#        [10.  ,  6.29,  0.  ],
#        [10.  ,  6.71,  0.  ],
#        [11.  ,  7.12,  1.  ],
#        [10.  ,  6.35,  0.  ],
#        [ 9.  ,  6.54,  0.  ],
#        [10.  ,  7.01,  0.  ],
#        [12.  ,  5.09,  1.  ],
#        [11.  ,  6.25,  1.  ],
#        [12.  ,  5.93,  1.  ],
#        [12.  ,  7.64,  1.  ],
#        [11.  ,  8.71,  1.  ],
#        [ 9.  ,  5.88,  0.  ],
#        [10.  ,  8.11,  1.  ],
#        [ 9.  ,  8.06,  0.  ],
#        [10.  ,  7.64,  0.  ],
#        [10.  ,  5.77,  0.  ],
#        [10.  ,  7.13,  0.  ],
#        [12.  ,  6.18,  1.  ],
#        [11.  ,  5.68,  1.  ],
#        [10.  ,  6.47,  0.  ],
#        [ 9.  ,  6.15,  0.  ],
#        [11.  ,  7.67,  1.  ],
#        [10.  ,  7.3 ,  0.  ],
#        [11.  ,  7.15,  1.  ],
# ...

# %%
new_df = pd.DataFrame(p.values, columns =  p.columns)
new_df
# Out:
#     cgpa  resume_score  placed
# 0   12.0          6.52     1.0
# 1   10.0          5.17     0.0
# 2   12.0          8.86     1.0
# 3   10.0          7.27     1.0
# 4   11.0          7.30     1.0
# ..   ...           ...     ...
# 95  10.0          6.38     0.0
# 96  12.0          7.76     1.0
# 97  10.0          7.78     0.0
# 98  12.0          5.63     1.0
# 99  10.0          6.61     0.0
#
# [100 rows x 3 columns]

# %%
q = p.columns.tolist()  # list of column labels
q
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
w = p.columns.values  # array of column labels
w
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
r = p.rename(columns = {'cgpa' : 'updated_cgpa',
                         'resume_score': 'score'})   # How to rename a column
r
# Out:
#     updated_cgpa  score  placed
# 0             12   6.52       1
# 1             10   5.17       0
# 2             12   8.86       1
# 3             10   7.27       1
# 4             11   7.30       1
# ..           ...    ...     ...
# 95            10   6.38       0
# 96            12   7.76       1
# 97            10   7.78       0
# 98            12   5.63       1
# 99            10   6.61       0
#
# [100 rows x 3 columns]
